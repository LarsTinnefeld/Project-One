# %%
import csv
with open("2019.csv") as csvdatei:
    csv_reader_object = csv.reader(csvdatei)
    for row in csv_reader_object:
        print(row)
# Out:
# ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
# ['1', 'Finland', '7.769', '1.340', '1.587', '0.986', '0.596', '0.153', '0.393']
# ['2', 'Denmark', '7.600', '1.383', '1.573', '0.996', '0.592', '0.252', '0.410']
# ['3', 'Norway', '7.554', '1.488', '1.582', '1.028', '0.603', '0.271', '0.341']
# ['4', 'Iceland', '7.494', '1.380', '1.624', '1.026', '0.591', '0.354', '0.118']
# ['5', 'Netherlands', '7.488', '1.396', '1.522', '0.999', '0.557', '0.322', '0.298']
# ['6', 'Switzerland', '7.480', '1.452', '1.526', '1.052', '0.572', '0.263', '0.343']
# ['7', 'Sweden', '7.343', '1.387', '1.487', '1.009', '0.574', '0.267', '0.373']
# ['8', 'New Zealand', '7.307', '1.303', '1.557', '1.026', '0.585', '0.330', '0.380']
# ['9', 'Canada', '7.278', '1.365', '1.505', '1.039', '0.584', '0.285', '0.308']
# ...

# %%
import pandas as pd

data = pd.read_csv("2019.csv") 

data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
import pandas as pd

data = pd.read_csv("2019.csv") 

data.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
import pandas as pd

data = pd.read_csv("2019.csv") 

data.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
import pandas as pd

data = pd.read_csv("2019.csv") 

data.head(100)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# ..           ...               ...    ...             ...             ...
# 95            96          Cameroon  5.044           0.549           0.910
# 96            97          Bulgaria  5.011           1.092           1.513
# 97            98             Ghana  4.996           0.611           0.868
# 98            99       Ivory Coast  4.944           0.569           0.808
# 99           100             Nepal  4.913           0.446           1.226
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
data[data["Country or region"]="Germany"]
# Out:
#   File "<ipython-input-6-a920316394da>", line 1
#     data[data["Country or region"]="Germany"]
#                                   ^
# SyntaxError: invalid syntax

# %%
data[data["Country or region"]=="Germany"]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 16            17           Germany  6.985           1.373           1.454
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 16                    0.987                         0.495       0.261
#
#     Perceptions of corruption
# 16                      0.265

# %%
data ["Country or region"]
# Out:
# 0                       Finland
# 1                       Denmark
# 2                        Norway
# 3                       Iceland
# 4                   Netherlands
#                  ...
# 151                      Rwanda
# 152                    Tanzania
# 153                 Afghanistan
# 154    Central African Republic
# 155                 South Sudan
# Name: Country or region, Length: 156, dtype: object

# %%
data ["Country or region"]=="Germany"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Country or region, Length: 156, dtype: bool

# %%
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data["Healthy life expectancy"])

# %%
data.corr()
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP per capita                   -0.801947  0.793883        1.000000
# Social support                   -0.767465  0.777058        0.754906
# Healthy life expectancy          -0.787411  0.779883        0.835462
# Freedom to make life choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions of corruption        -0.351959  0.385613        0.298920
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# ...

# %%
sns.pairplot(data)

# %%
sns.barplot(x="Healthy life expectancy",
           y="GDP per capita",
           data=data)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x="Healthy life expectancy",
           y="GDP per capita",
           data=data)

# %%
plt.figure(figsize=(18,5))
import numpy as np
plt.xticks(np.arange(5),rotation=90)
sns.barplot(x="Healthy life expectancy",
           y="GDP per capita",
           data=data)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(['Score','Country or region'], axis=1)

# %%
x
# Out:
#      Overall rank  GDP per capita  Social support  Healthy life expectancy  \
# 0               1           1.340           1.587                    0.986
# 1               2           1.383           1.573                    0.996
# 2               3           1.488           1.582                    1.028
# 3               4           1.380           1.624                    1.026
# 4               5           1.396           1.522                    0.999
# ..            ...             ...             ...                      ...
# 151           152           0.359           0.711                    0.614
# 152           153           0.476           0.885                    0.499
# 153           154           0.350           0.517                    0.361
# 154           155           0.026           0.000                    0.105
# 155           156           0.306           0.575                    0.295
#
# ...

# %%
y = data['Score']

# %%
y
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.33)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit (x_train, y_train) #Fehlersuche
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = lm.predict(x_test)

# %%
plt.scatter(y_test, predictions)
plt.xlabel('y Test values (True values)')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
from sklearn import metrics

# %%
print("MEA", metrics.mean_absolute_error(y_test,predictions))
print("MSE", metrics.mean_squared_error(y_test,predictions))
print("RMSE", np.sqrt(metrics.mean_absolute_error(y_test,predictions)))
# Out:
# MEA 0.11511600884625253
# MSE 0.024755667586908302
# RMSE 0.3392875017536787

# %%
metrics.explained_variance_score(y_test,predictions)
# Out:
# 0.9724422985431066

# %%
cdf = pd.DataFrame(lm.coef_, x.columns, columns=['Coeff'])
cdf
# Out:
#                                  Coeff
# Overall rank                 -0.024005
# GDP per capita               -0.091193
# Social support                0.292975
# Healthy life expectancy      -0.156111
# Freedom to make life choices -0.093163
# Generosity                    0.109607
# Perceptions of corruption     0.588035
